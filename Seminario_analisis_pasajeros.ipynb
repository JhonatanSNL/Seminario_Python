# %% [markdown]
# <a href="https://colab.research.google.com/github/JhonatanSNL/Seminario_Python/blob/main/Seminario_analisis_pasajeros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### pip install pandas matplotlib jupyter seaborn numpy scikit-learn.

# %%
### pip install pandas matplotlib jupyter seaborn numpy scikit-learn.

# %% [markdown]
# ### Inicio de codigo

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
aeropuerto_df = pd.read_csv("https://raw.githubusercontent.com/JhonatanSNL/Seminario_Python/refs/heads/main/salida_mensual_pasajeros_aeropuerto_destino_internacional%20Arreglado.csv")

# %%
aeropuerto_df
# Out:
#      sal_codigo         sal_destinoint sal_indicador  sal_periodo  sal_valor
# 0            EC                Ecuador    SALIDA_PAX       202209       1058
# 1            KR          Corea del Sur    SALIDA_PAX       202209          1
# 2            BB               Barbados    SALIDA_PAX       202209          1
# 3            IL                 Israel    SALIDA_PAX       202209         23
# 4            KY           Islas Caimán    SALIDA_PAX       202209          1
# ...         ...                    ...           ...          ...        ...
# 7055         FR                Francia    SALIDA_PAX       200701         67
# 7056         AN  Antillas Neerlandesas    SALIDA_PAX       200701        906
# 7057         EC                Ecuador    SALIDA_PAX       200701       1752
# 7058         NI              Nicaragua    SALIDA_PAX       200701         15
# 7059         TT      Trinidad y Tobago    SALIDA_PAX       200701         36
#
# [7060 rows x 5 columns]

# %%
type(aeropuerto_df)
# Out:
# pandas.core.frame.DataFrame

# %%
aeropuerto_df.info() #nos permite ver la info del archivo dt(dataframe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7060 entries, 0 to 7059
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sal_codigo      7060 non-null   object
#  1   sal_destinoint  7060 non-null   object
#  2   sal_indicador   7060 non-null   object
#  3   sal_periodo     7060 non-null   int64
#  4   sal_valor       7060 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 275.9+ KB

# %%
aeropuerto_df.dtypes #nos permite ver los tipos de datos
# Out:
# sal_codigo        object
# sal_destinoint    object
# sal_indicador     object
# sal_periodo        int64
# sal_valor          int64
# dtype: object

# %%
aeropuerto_df.columns #nos permite ver los nombres de las columnas
# Out:
# Index(['sal_codigo', 'sal_destinoint', 'sal_indicador', 'sal_periodo',
#        'sal_valor'],
#       dtype='object')

# %%
aeropuerto_df.tail() #nos permite ver los ultimos datos
# Out:
#      sal_codigo         sal_destinoint sal_indicador  sal_periodo  sal_valor
# 7055         FR                Francia    SALIDA_PAX       200701         67
# 7056         AN  Antillas Neerlandesas    SALIDA_PAX       200701        906
# 7057         EC                Ecuador    SALIDA_PAX       200701       1752
# 7058         NI              Nicaragua    SALIDA_PAX       200701         15
# 7059         TT      Trinidad y Tobago    SALIDA_PAX       200701         36

# %%
aeropuerto_df.head(30) #nos permite ver los primeros datos
# Out:
#    sal_codigo         sal_destinoint sal_indicador  sal_periodo  sal_valor
# 0          EC                Ecuador    SALIDA_PAX       202209       1058
# 1          KR          Corea del Sur    SALIDA_PAX       202209          1
# 2          BB               Barbados    SALIDA_PAX       202209          1
# 3          IL                 Israel    SALIDA_PAX       202209         23
# 4          KY           Islas Caimán    SALIDA_PAX       202209          1
# 5          CA                 Canadá    SALIDA_PAX       202209        740
# 6          SA         Arabia Saudita    SALIDA_PAX       202209          1
# 7          IT                 Italia    SALIDA_PAX       202209        417
# 8          GB            Reino Unido    SALIDA_PAX       202209        560
# 9          JM                Jamaica    SALIDA_PAX       202209         11
# 10         SV            El Salvador    SALIDA_PAX       202209        155
# 11         PA                 Panamá    SALIDA_PAX       202209      27639
# 12         US         Estados Unidos    SALIDA_PAX       202209      41865
# 13         ES                 España    SALIDA_PAX       202209       8575
# 14         PY               Paraguay    SALIDA_PAX       202209         41
# 15         HT                  haiti    SALIDA_PAX       202209          1
# 16         BR                 Brasil    SALIDA_PAX       202209       1126
# 17         AN  Antillas Neerlandesas    SALIDA_PAX       202209       1208
# 18         QA                  Qatar    SALIDA_PAX       202209         20
# 19         DO   República Dominicana    SALIDA_PAX       202209       9445
# 20         UY                Uruguay    SALIDA_PAX       202209         29
# 21         CL                  Chile    SALIDA_PAX       202209        505
# 22         TT      Trinidad y Tobago    SALIDA_PAX       202209         17
# 23         CR             Costa Rica    SALIDA_PAX       202209       1690
# 24         GR                 Grecia    SALIDA_PAX       202209          2
# 25         NL           Países Bajos    SALIDA_PAX       202209         52
# 26         MX                 México    SALIDA_PAX       202209      16548
# 27         FR                Francia    SALIDA_PAX       202209         55
# 28         PR            Puerto Rico    SALIDA_PAX       202209        632
# 29         BO                Bolivia    SALIDA_PAX       202209         49

# %%
aeropuerto_df.iloc[20:30:2,0:5] #nos permite ver los datos de las filas y columnas [Fila I:Fila F:rango de salto entre columnas, Columna I:Columna F]
# Out:
#    sal_codigo     sal_destinoint sal_indicador  sal_periodo  sal_valor
# 20         UY            Uruguay    SALIDA_PAX       202209         29
# 22         TT  Trinidad y Tobago    SALIDA_PAX       202209         17
# 24         GR             Grecia    SALIDA_PAX       202209          2
# 26         MX             México    SALIDA_PAX       202209      16548
# 28         PR        Puerto Rico    SALIDA_PAX       202209        632

# %%
pd.unique(aeropuerto_df['sal_indicador']) #nos permite ver los datos unicos de una columna
# Out:
# array(['SALIDA_PAX'], dtype=object)

# %%
pd.unique(aeropuerto_df['sal_codigo'])
#pd.unique(aeropuerto_df['sal_codigo']).size   #nos permite ver la cantidad de datos unicos de una columna
# Out:
# array(['EC', 'KR', 'BB', 'IL', 'KY', 'CA', 'SA', 'IT', 'GB', 'JM', 'SV',
#        'PA', 'US', 'ES', 'PY', 'HT', 'BR', 'AN', 'QA', 'DO', 'UY', 'CL',
#        'TT', 'CR', 'GR', 'NL', 'MX', 'FR', 'PR', 'BO', 'BE', 'GT', 'TR',
#        'PT', 'AR', 'SE', 'PE', 'CH', 'HN', 'DE', 'KN', 'BS', 'CN', 'AG',
#        'JP', 'HK', 'GY', 'BZ', 'VE', 'IN', 'CU', 'NZ', 'AT', 'JO', 'IE',
#        'SN', 'NO', 'DK', 'NI', 'MA', 'HR', 'ZA', 'LC', 'KP', 'AU', 'SR',
#        'CO', 'BM', 'AE', 'PH', 'DM', 'HU', 'RU', 'GP', 'LU', 'LB', 'IR',
#        'RO', 'AO', 'MY', 'LV'], dtype=object)

# %%
pd.unique(aeropuerto_df['sal_destinoint'])
# Out:
# array(['Ecuador', 'Corea del Sur', 'Barbados', 'Israel', 'Islas Caimán',
#        'Canadá', 'Arabia Saudita', 'Italia', 'Reino Unido', 'Jamaica',
#        'El Salvador', 'Panamá', 'Estados Unidos', 'España', 'Paraguay',
#        'haiti', 'Brasil', 'Antillas Neerlandesas', 'Qatar',
#        'República Dominicana', 'Uruguay', 'Chile', 'Trinidad y Tobago',
#        'Costa Rica', 'Grecia', 'Países Bajos', 'México', 'Francia',
#        'Puerto Rico', 'Bolivia', 'Bélgica', 'Guatemala', 'Turquía',
#        'Portugal', 'Argentina', 'Suecia', 'Perú', 'Suiza', 'Honduras',
#        'Alemania', 'San Cristóbal y Nieves', 'Bahamas', 'China',
#        'Antigua and Barbuda', 'Japón', 'Hong Kong', 'Guyana', 'Belice',
#        'Venezuela', 'india', 'Cuba', 'Nueva Zelanda', 'Austria',
#        'antigua and barbuda', 'Jordania', 'Irlanda', 'Senegal', 'Noruega',
#        'Dinamarca', 'Nicaragua', 'Marruecos', 'CROACIA', 'Sudáfrica',
#        'Haití', 'saint lucia', 'Corea del Norte', 'Australia', 'Surinam',
#        'Colombia', 'Bermudas', 'Emiratos Árabes Unidos', 'Filipinas',
#        'Dominica', 'Hungría', 'Rusia', 'Santa Lucia', 'Guadalupe',
#        'Luxemburgo', 'Líbano', 'Irán', 'Rumania', 'Angola', 'Malasia',
#        'Letonia'], dtype=object)

# %%
aeropuerto_df['sal_valor'].describe()
# Out:
# count     7060.000000
# mean      1458.611898
# std       4606.916483
# min         -1.000000
# 25%          7.000000
# 50%         82.000000
# 75%        559.250000
# max      52617.000000
# Name: sal_valor, dtype: float64

# %%
aeropuerto_df.min()
# Out:
# sal_codigo                AE
# sal_destinoint      Alemania
# sal_indicador     SALIDA_PAX
# sal_periodo           200701
# sal_valor                 -1
# dtype: object

# %%
aeropuerto_df.max()
# Out:
# sal_codigo                 ZA
# sal_destinoint    saint lucia
# sal_indicador      SALIDA_PAX
# sal_periodo            202302
# sal_valor               52617
# dtype: object

# %%
aeropuerto_df.count()
# Out:
# sal_codigo        7060
# sal_destinoint    7060
# sal_indicador     7060
# sal_periodo       7060
# sal_valor         7060
# dtype: int64

# %%
#elemento clave : elemento valor
column_rename_map = {
    "sal_codigo": "codigo_pais",
    "sal_destinoint": "pais_destino",
    "sal_indicador": "indicador_salida",
    "sal_periodo": "periodo",
    "sal_valor": "valor_salida"
}

# %%
aeropuerto_df_renombrado = aeropuerto_df.rename(columns=column_rename_map)

# %%
aeropuerto_df_renombrado.head()
# Out:
#   codigo_dt     destino_dt indicador_dt  periodo_dt  valor_dt
# 0        EC        Ecuador   SALIDA_PAX      202209      1058
# 1        KR  Corea del Sur   SALIDA_PAX      202209         1
# 2        BB       Barbados   SALIDA_PAX      202209         1
# 3        IL         Israel   SALIDA_PAX      202209        23
# 4        KY   Islas Caimán   SALIDA_PAX      202209         1

# %% [markdown]
# ### Cual es el pais mas visitado este año.

# %%
aeropuerto_df_renombrado = aeropuerto_df.rename(columns=column_rename_map)

aeropuerto_df_renombrado.head()

plt.figure(figsize=(18, 10))
frecuencia_paises = aeropuerto_df_renombrado['codigo_pais'].value_counts()

ax = frecuencia_paises.plot(kind='bar', color='skyblue', edgecolor='black')
umbral = 50

for p in ax.patches:
    if p.get_height() > umbral:
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points', rotation=45)
plt.xticks(rotation=45, ha='right')

plt.title('Frecuencia de codigo_pais')

plt.xlabel('Código de País')

plt.ylabel('Frecuencia')

plt.tight_layout()

plt.show()

# %% [markdown]
# La frecuencia de registros por país varía significativamente. Los primeros países en la lista (por ejemplo, US, EC, PA y DO), tienen una frecuencia muy alta en comparación con otros países. Hay una disminución gradual en la frecuencia a medida que se avanza hacia la derecha en el gráfico, lo que indica que hay países con muy pocos registros. La gráfica presenta una "cola larga" (long tail) donde muchos países tienen una frecuencia baja, Esto sugiere que mientras unos pocos destinos son muy comunes, hay una gran cantidad de destinos que son relativamente infrecuentes.

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# ### Tendencia cronologica de los viajes

# %%
aeropuerto_df_renombrado['periodo'] = pd.to_datetime(aeropuerto_df_renombrado['periodo'], format='%Y%m')
tendencias_temporales = aeropuerto_df_renombrado.groupby('periodo')['valor_salida'].sum().reset_index()

plt.figure(figsize=(14, 8))
plt.plot(tendencias_temporales['periodo'], tendencias_temporales['valor_salida'], marker='o', linestyle='-', color='blue', label='Valor de Salida')

plt.fill_between(tendencias_temporales['periodo'], tendencias_temporales['valor_salida'], color='skyblue', alpha=0.3)
plt.fill_between(tendencias_temporales['periodo'], 0, tendencias_temporales['valor_salida'], where=(tendencias_temporales['periodo'] < '2020-01-01'), color='lightgreen', alpha=0.5, label='Antes de 2020')
plt.fill_between(tendencias_temporales['periodo'], 0, tendencias_temporales['valor_salida'], where=(tendencias_temporales['periodo'] >= '2020-01-01'), color='lightcoral', alpha=0.5, label='Desde 2020')

plt.title('Tendencia de valor_salida a lo largo del tiempo')
plt.xlabel('Periodo')
plt.ylabel('Valor de Salida')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# A lo largo de los años, hay una tendencia general ascendente en el valor de salidas de pasajeros, esto sugiere un crecimiento en el número de salidas de pasajeros a lo largo del tiempo. Es posible que ciertos meses del año vean un aumento o disminución en el número de salidas, lo cual es común en la industria de viajes debido a las vacaciones y otros factores estacionales. Hay una caída pronunciada y significativa en el valor de salidas de pasajeros alrededor de 2020. Esta caída puede corresponder al inicio de la pandemia de COVID-19, que tuvo un fuerte impacto en los viajes internacionales. Posteriormente, se observa una recuperación a medida que avanza el tiempo hacia 2021 y 2022, aunque con cierta volatilidad.

# %%
#Verificar columnas necesarias
if 'periodo' in aeropuerto_df_renombrado.columns and 'valor_salida' in aeropuerto_df_renombrado.columns:

    # Asegurar que periodo_dt sea datetime
    aeropuerto_df_renombrado['periodo'] = pd.to_datetime(aeropuerto_df_renombrado['periodo'])

    # Crear columna "Año-Mes" en formato YYYY-MM
    aeropuerto_df_renombrado['year_month'] = aeropuerto_df_renombrado['periodo'].dt.to_period('M').astype(str)

    # Agrupar por año-mes y sumar pasajeros
    tendencia_mensual = aeropuerto_df_renombrado.groupby('year_month')['valor_salida'].sum().reset_index()
    tendencia_mensual.columns = ['Mes', 'Total de Pasajeros']

    # Convertir 'Mes' a datetime para ordenarlo
    tendencia_mensual['Mes'] = pd.to_datetime(tendencia_mensual['Mes'])
    tendencia_mensual = tendencia_mensual.sort_values('Mes')

    # Mostrar tabla (opcional)
    print("Tendencia de viajes por mes:")
    display(tendencia_mensual)

    # Graficar
    plt.figure(figsize=(16, 6))

    # Dibujar línea de tendencia completa
    plt.plot(tendencia_mensual['Mes'], tendencia_mensual['Total de Pasajeros'], linestyle='-', color='gray', alpha=0.5)

    # Rellenar el área debajo de la curva con color verde
    plt.fill_between(tendencia_mensual['Mes'], tendencia_mensual['Total de Pasajeros'],
                 color='green', alpha=0.3)

    # Colores intercalados: azul y rojo
    colores = ['dodgerblue', 'crimson']

    # Dibujar puntos intercalando colores
    for i, row in tendencia_mensual.iterrows():
        color = colores[i % 2]  # alterna entre 0 y 1
        plt.plot(row['Mes'], row['Total de Pasajeros'], marker='o', color=color)

    # Ajustes visuales
    plt.title('📈 Tendencia de Viajes por Mes (colores intercalados)', fontsize=16)
    plt.xlabel('Mes', fontsize=12)
    plt.ylabel('Total de Pasajeros', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

else:
    print("Las columnas 'periodo_dt' y/o 'valor_dt' no se encuentran en el DataFrame.")
# Out:
# Tendencia de viajes por mes:
#            Mes  Total de Pasajeros
# 0   2007-01-01               33981
# 1   2007-02-01               18209
# 2   2007-03-01               21678
# 3   2007-04-01               21842
# 4   2007-05-01               21012
# ..         ...                 ...
# 189 2022-10-01              126980
# 190 2022-11-01              125152
# 191 2022-12-01              129342
# 192 2023-01-01              143091
# 193 2023-02-01              108993
#
# [194 rows x 2 columns]
# /tmp/ipython-input-104-576341644.py:46: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Rank de los 6 paises mas visitados (1 por 1)

# %% [markdown]
# top_6_paises = aeropuerto_df_renombrado['codigo_pais'].value_counts().head(6).index
#
# plt.figure(figsize=(20, 12))
#
# for i, pais in enumerate(top_6_paises, 1):
#     pais_data = aeropuerto_df_renombrado[aeropuerto_df_renombrado['codigo_pais'] == pais].copy()
#     pais_data.loc[:, 'periodo'] = pd.to_datetime(pais_data['periodo'], format='%Y%m')
#     tendencias_pais = pais_data.groupby('periodo')['valor_salida'].sum().reset_index()
#
#     # Subgráfica individual para cada país
#     plt.subplot(3, 2, i)
#     plt.plot(tendencias_pais['periodo'], tendencias_pais['valor_salida'], marker='o', linestyle='-', label=pais)
#     plt.title(f'Tendencia de valor_salida para {pais}')
#     plt.xlabel('Periodo')
#     plt.ylabel('Valor de Salida')
#     plt.grid(True)
#     plt.xticks(rotation=45)
#     plt.legend()
#
# plt.tight_layout()
# plt.show()

# %%
# prompt: Rank de los 6 paises mas visitados (1 por 1), en graficas d etendencia

# Agrupar por país de destino y sumar el valor de salida para obtener el total por país
total_por_pais = aeropuerto_df_renombrado.groupby('pais_destino')['valor_salida'].sum().reset_index()

# Ordenar por valor de salida de forma descendente y seleccionar los top 6
top_6_paises = total_por_pais.sort_values(by='valor_salida', ascending=False).head(6)

print("Top 6 países más visitados (por valor de salida total):")
print(top_6_paises)

# Ahora, graficar la tendencia para cada uno de los 6 países principales
print("\nGraficando la tendencia para cada uno de los top 6 países:")

for index, row in top_6_paises.iterrows():
    pais = row['pais_destino']

    # Filtrar el DataFrame para obtener solo los datos de este país
    df_pais = aeropuerto_df_renombrado[aeropuerto_df_renombrado['pais_destino'] == pais].copy()

    # Asegurarse de que la columna 'periodo' sea de tipo datetime
    df_pais['periodo'] = pd.to_datetime(df_pais['periodo'])

    # Agrupar por periodo y sumar el valor de salida para este país
    tendencia_pais = df_pais.groupby('periodo')['valor_salida'].sum().reset_index()

    # Ordenar por periodo
    tendencia_pais = tendencia_pais.sort_values('periodo')

    # Graficar la tendencia
    plt.figure(figsize=(14, 6))
    plt.plot(tendencia_pais['periodo'], tendencia_pais['valor_salida'], marker='o', linestyle='-')
    plt.title(f'Tendencia de Viajes a {pais} a lo largo del tiempo')
    plt.xlabel('Periodo')
    plt.ylabel('Valor de Salida')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# Top 6 países más visitados (por valor de salida total):
#             pais_destino  valor_salida
# 30        Estados Unidos       3998789
# 58                Panamá       2652481
# 54                México        798639
# 29                España        671741
# 61                  Perú        424368
# 66  República Dominicana        260874
#
# Graficando la tendencia para cada uno de los top 6 países:

# %% [markdown]
# A lo largo de los años, hay una tendencia general ascendente en el valor de salidas de pasajeros, esto sugiere un crecimiento en el número de salidas de pasajeros a lo largo del tiempo. Es posible que ciertos meses del año vean un aumento o disminución en el número de salidas, lo cual es común en la industria de viajes debido a las vacaciones y otros factores estacionales. Hay una caída pronunciada y significativa en el valor de salidas de pasajeros alrededor de 2020. Esta caída puede corresponder al inicio de la pandemia de COVID-19, que tuvo un fuerte impacto en los viajes internacionales. Posteriormente, se observa una recuperación a medida que avanza el tiempo hacia 2021 y 2022, aunque con cierta volatilidad.

# %% [markdown]
# ### Comparar el rank de los 6 paises en un solo grafico.

# %%
# prompt: Comparar el rank de los 6 paises en un solo grafico.

# Ahora, comparar el rank de los 6 países en un solo gráfico
print("\nComparando la tendencia de los top 6 países en un solo gráfico:")

plt.figure(figsize=(16, 10))

# Iterar sobre los top 6 países y graficar su tendencia
for index, row in top_6_paises.iterrows():
    pais = row['pais_destino']

    # Filtrar el DataFrame para obtener solo los datos de este país
    df_pais = aeropuerto_df_renombrado[aeropuerto_df_renombrado['pais_destino'] == pais].copy()

    # Asegurarse de que la columna 'periodo' sea de tipo datetime
    df_pais['periodo'] = pd.to_datetime(df_pais['periodo'])

    # Agrupar por periodo y sumar el valor de salida para este país
    tendencia_pais = df_pais.groupby('periodo')['valor_salida'].sum().reset_index()

    # Ordenar por periodo
    tendencia_pais = tendencia_pais.sort_values('periodo')

    # Graficar la tendencia en el mismo gráfico
    plt.plot(tendencia_pais['periodo'], tendencia_pais['valor_salida'], marker='o', linestyle='-', label=pais)

# Ajustes visuales para el gráfico combinado
plt.title('Tendencia Comparada de Viajes a los Top 6 Países a lo largo del tiempo', fontsize=16)
plt.xlabel('Periodo', fontsize=12)
plt.ylabel('Valor de Salida', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.legend(title='País de Destino')
plt.tight_layout()
plt.show()
# Out:
# Comparando la tendencia de los top 6 países en un solo gráfico:

# %% [markdown]
# Impacto de la Pandemia: Todos los países muestran una caída notable alrededor de 2020 debido a la pandemia de COVID-19. Esta caída es más pronunciada en Estados Unidos y Ecuador. Recuperación Post-pandemia: La recuperación post-pandemia es más evidente en Estados Unidos y Ecuador, con valores de salida que superan los niveles pre-pandemia. Panamá y República Dominicana también muestran recuperación, aunque más gradual. Variabilidad: Estados Unidos muestra la mayor variabilidad en los valores de salida, con picos y caídas pronunciados. Otros países como Ecuador y Panamá tienen variabilidades más moderadas. Tendencias de Crecimiento: A lo largo de los años, Estados Unidos y Ecuador muestran las tendencias de crecimiento más fuertes, lo que podría indicar un aumento en la popularidad de estos destinos o un crecimiento en el tráfico aéreo internacional.

# %% [markdown]
# ### analisis del pais mas visitado

# %%
us_data = aeropuerto_df_renombrado[aeropuerto_df_renombrado['codigo_pais'] == 'US'].copy()
us_data.loc[:, 'periodo'] = pd.to_datetime(us_data['periodo'], format='%Y%m')
us_data['año'] = us_data['periodo'].dt.year
us_data['mes'] = us_data['periodo'].dt.month
mejor_mes_por_año = us_data.groupby(['año', 'mes'])['valor_salida'].sum().reset_index()
mejor_mes_por_año = mejor_mes_por_año.loc[mejor_mes_por_año.groupby('año')['valor_salida'].idxmax()]
print(mejor_mes_por_año)

plt.figure(figsize=(14, 8))
plt.plot(mejor_mes_por_año['año'].astype(str) + '-' + mejor_mes_por_año['mes'].astype(str),
         mejor_mes_por_año['valor_salida'], marker='o', linestyle='-', color='b')
plt.title('Mejor mes de cada año para US en términos de valor_salida')
plt.xlabel('Año-Mes')
plt.ylabel('Valor de Salida')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

moda_mes = mejor_mes_por_año['mes'].mode()[0]
print(f"La moda del mes es: {moda_mes}")
frecuencia_meses = mejor_mes_por_año['mes'].value_counts()

plt.figure(figsize=(10, 6))
frecuencia_meses.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Frecuencia de los mejores meses en términos de valor_salida')
plt.xlabel('Mes')
plt.ylabel('Frecuencia')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
#       año  mes  valor_salida
# 0    2007    1         16643
# 12   2008    1         16222
# 31   2009    8         21576
# 43   2010    8         22100
# 48   2011    1         20874
# 67   2012    8         16918
# 83   2013   12         21843
# 91   2014    8         22464
# 107  2015   12         24995
# 115  2016    8         30412
# 127  2017    8         28697
# 143  2018   12         29988
# 151  2019    8         33343
# 156  2020    1         32512
# 173  2021    6         48102
# 187  2022    8         52617
# 192  2023    1         45666
# La moda del mes es: 8

# %% [markdown]
# Podemos decir que Agosto es el mejor mes para salidas a Estados Unidos puede ser debido a una combinación de factores como: las vacaciones escolares de verano, el clima favorable, eventos y festivales, promociones de viajes, y la estacionalidad general en la industria del turismo. Estos factores contribuyen a un aumento significativo en el valor_salida durante este mes.
